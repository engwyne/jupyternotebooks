# %%
import numpy as np
import datetime as dt
import pandas as pd
import matplotlib.pyplot as plt
loged=pd.read_csv('log_temp.csv')
loged=loged.rename(columns={'3/14/19':'date','19:33:07':'time','T=22.0':'temp','H=20.0':'humidity'} )
loged
# Out:
#         Date      Time Temparature Humidity
# 0    3/14/19  19:33:07      T=22.0   H=20.0
# 1    3/14/19  19:38:10      T=22.0   H=20.0
# 2    3/14/19  19:43:11      T=22.0   H=26.0
# 3    3/14/19  19:48:14      T=22.0   H=26.0
# 4    3/14/19  19:53:15      T=22.0   H=20.0
# ..       ...       ...         ...      ...
# 331  3/15/19  23:48:51      T=18.0   H=28.0
# 332  3/15/19  23:53:51      T=18.0   H=22.0
# 333  3/15/19  23:58:52      T=18.0   H=22.0
# 334  3/16/19  00:03:52      T=18.0   H=22.0
# 335  3/16/19  00:08:53      T=18.0   H=22.0
#
# [336 rows x 4 columns]

# %%
loged['Temparature'] = loged['Temparature'].str.replace('T', '')
loged['Temparature'] = loged['Temparature'].str.replace('=', '')
loged['Humidity'] = loged['Humidity'].str.replace('H', '')
loged['Humidity'] = loged['Humidity'].str.replace('=', '')

loged.to_csv (r'C:\Users\headybii\Desktop\Data_projects.csv', index=False)

loged
# Out:
#         Date      Time Temparature Humidity
# 0    3/14/19  19:33:07        22.0     20.0
# 1    3/14/19  19:38:10        22.0     20.0
# 2    3/14/19  19:43:11        22.0     26.0
# 3    3/14/19  19:48:14        22.0     26.0
# 4    3/14/19  19:53:15        22.0     20.0
# ..       ...       ...         ...      ...
# 331  3/15/19  23:48:51        18.0     28.0
# 332  3/15/19  23:53:51        18.0     22.0
# 333  3/15/19  23:58:52        18.0     22.0
# 334  3/16/19  00:03:52        18.0     22.0
# 335  3/16/19  00:08:53        18.0     22.0
#
# [336 rows x 4 columns]

# %%
date=loged['date']
temp=loged['temp']
plt.hist (temp)
# Out:
# (array([101.,  41.,  84.,  12.,   5.,  20.,  10.,  10.,   4.,  48.]),
#  array([ 0. ,  2.4,  4.8,  7.2,  9.6, 12. , 14.4, 16.8, 19.2, 21.6, 24. ]),
#  <BarContainer object of 10 artists>)

# %%
humidity=loged['humidity']
temp=loged['temp']
plt.plot (temp,humidity)
plot.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15628/659406523.py in <module>
#       1 humidity=loged['humidity']
#       2 temp=loged['temp']
# ----> 3 plt.plot (temp,humidity)
#       4 plot.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...
